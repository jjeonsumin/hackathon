# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier

# 데이터 로드
data = pd.read_csv("C:/apps/hct/datasets/하이닉스 scaling2.csv", encoding="cp949")

# %%
data.head()
# Out:
#    Unnamed: 0          날짜        시가        고가        저가        종가       거래량  \
# 0           0  2014-03-21 -0.851149 -0.834894 -0.835520 -0.821074  0.462306
# 1           1  2014-03-24 -0.824176 -0.833908 -0.823411 -0.832008 -0.136175
# 2           2  2014-03-25 -0.834166 -0.843765 -0.833502 -0.842942 -0.365318
# 3           3  2014-03-26 -0.837163 -0.841794 -0.830474 -0.827038 -0.345917
# 4           4  2014-03-27 -0.838162 -0.841794 -0.832492 -0.840954 -0.335508
#
#        MACD  MACD_Signal       RSI  ...  [일]기타금융_수량  [일]은행_수량  [일]투신_수량  \
# 0 -0.300861    -0.253689 -0.227448  ...    0.307563  4.527523  3.981942
# 1 -0.274031    -0.260423 -0.436816  ...    0.000000 -1.894648 -0.586656
# 2 -0.274841    -0.265984 -0.845870  ...    0.682231 -6.599847  1.069135
# 3 -0.240902    -0.263194 -0.381208  ...    0.000000 -0.015291  0.290529
# 4 -0.242786    -0.261363 -0.431351  ...   -0.528450  3.006881 -0.458782
#
#    [일]보험_수량  [일]금융투자_수량  [일]기관_수량  [일]외국인_수량  [일]개인_수량  [일]프로그램순매수(종목)  target
# 0  2.029861    0.183384  1.331608   1.374596 -1.928576        1.100531      -1
# 1 -0.748527    0.346853  0.043044  -0.079842  0.107574       -1.931517       1
# 2 -0.588008    0.388900  0.176883  -0.702910  0.484881        0.324422       1
# 3  1.743246    0.036680  0.237142   0.252018 -0.352650        1.313001      -1
# 4 -0.578367    0.407798  0.176055  -1.613751  1.214745       -2.218120       1
#
# [5 rows x 93 columns]

# %%
X = data.drop(['날짜','target'], axis=1)
y = data['target']

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import f_regression, SelectFromModel
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import ttest_ind

# Assuming 'df' is the DataFrame with the preprocessed and scaled data

# Remove the first row if it's the date column (assuming 'df' does not include the date column already)
# X = df.drop(['target_label'], axis=1)
# y = df['target_label']

# Step 5: Correlation for Forward Selection
# correlations = X.corrwith(y).abs().sort_values(ascending=False)

# Step 6: T-test for mean differences between label groups
# t_tests = {column: ttest_ind(X[column][y == 1], X[column][y == -1], nan_policy='omit') for column in X.columns}
# t_tests_sorted = sorted(t_tests.items(), key=lambda x: x[1].pvalue)

# Step 7: Lasso and Ridge for embedded methods
# lasso = LassoCV().fit(X, y)
# ridge = RidgeCV().fit(X, y)

# lasso_importance = np.abs(lasso.coef_)
# ridge_importance = np.abs(ridge.coef_)

# features_lasso_sorted = sorted(zip(X.columns, lasso_importance), key=lambda x: x[1], reverse=True)
# features_ridge_sorted = sorted(zip(X.columns, ridge_importance), key=lambda x: x[1], reverse=True)

# Step 8: Random Forest for feature importance
rf = RandomForestRegressor()
rf.fit(X, y)

features_rf_sorted = sorted(zip(X.columns, rf.feature_importances_), key=lambda x: x[1], reverse=True) 
# data.to_csv("C:/apps/hct/datasets/하이닉스_f_select.csv", encoding="cp949")
# Output (not printed to adhere to the request for no explanations, adjust as needed for actual output)

# %%
t_tests_sorted
# Out:
# [('시가_대비_고가_등락률',
#   TtestResult(statistic=3.6035232094139786, pvalue=0.0003201691112434742, df=2457.0)),
#  ('고가_등락률',
#   TtestResult(statistic=3.2887310959643687, pvalue=0.0010205974256534878, df=2457.0)),
#  ('[일]기관_수량',
#   TtestResult(statistic=3.0074080182609624, pvalue=0.0026615748576086957, df=2457.0)),
#  ('[일]개인_수량',
#   TtestResult(statistic=-2.6914139168592297, pvalue=0.007163211765800349, df=2457.0)),
#  ('[일]사모펀드_수량',
#   TtestResult(statistic=2.6413236857384534, pvalue=0.008310608558869705, df=2457.0)),
#  ('[일]보험_수량',
#   TtestResult(statistic=2.447629949794881, pvalue=0.014449464764800342, df=2457.0)),
#  ('[일]투신_수량',
#   TtestResult(statistic=2.4455744806052606, pvalue=0.014531887325788917, df=2457.0)),
#  ('저가_등락률',
#   TtestResult(statistic=2.1738019831016127, pvalue=0.0298151932696607, df=2457.0)),
#  ('SMA_120_등락률',
#   TtestResult(statistic=2.1299097020326365, pvalue=0.03327818126420653, df=2457.0)),
#  ('SMA_240',
#   TtestResult(statistic=-2.1083774601137657, pvalue=0.03509934792733331, df=2457.0)),
#  ('EMA_240',
#   TtestResult(statistic=-2.008606971273709, pvalue=0.0446880591531783, df=2457.0)),
#  ('Unnamed: 0',
#   TtestResult(statistic=-1.997850737834214, pvalue=0.045842902504884465, df=2457.0)),
#  ('SMA_240_등락률',
#   TtestResult(statistic=1.980031217478648, pvalue=0.04781142556159271, df=2457.0)),
#  ('EMA_240_등락률',
#   TtestResult(statistic=1.911729096417424, pvalue=0.056027157719944994, df=2457.0)),
#  ('저가_대비_고가_등락률',
#   TtestResult(statistic=1.8977912047781786, pvalue=0.05784070352032122, df=2457.0)),
#  ('종가_등락률',
#   TtestResult(statistic=1.8418289934788894, pvalue=0.06562061889621697, df=2457.0)),
#  ('EMA_5_등락률',
#   TtestResult(statistic=1.7915766146729668, pvalue=0.07332383667986125, df=2457.0)),
#  ('SMA_120',
#   TtestResult(statistic=-1.7312187074088015, pvalue=0.08353829692822054, df=2457.0)),
#  ('EMA_120',
#   TtestResult(statistic=-1.7016228366426314, pvalue=0.08895260906940039, df=2457.0)),
#  ('EMA_60_minus_EMA_240',
#   TtestResult(statistic=1.6304978915949915, pvalue=0.10312448182325563, df=2457.0)),
#  ('시가_대비_저가_등락률',
#   TtestResult(statistic=1.6220374672541271, pvalue=0.104923626066205, df=2457.0)),
#  ('EMA_120_minus_EMA_240',
#   TtestResult(statistic=1.6052122217216225, pvalue=0.10857562059171602, df=2457.0)),
#  ('MACD_Signal_등락률',
#   TtestResult(statistic=-1.5820797756781841, pvalue=0.11376006631791613, df=2457.0)),
#  ('EMA_120_등락률',
#   TtestResult(statistic=1.5678084355542354, pvalue=0.1170546157667656, df=2457.0)),
#  ('SMA_60_minus_SMA_240',
#   TtestResult(statistic=1.5301552745781934, pvalue=0.12610702923814554, df=2457.0)),
#  ('EMA_60_minus_EMA_120',
#   TtestResult(statistic=1.509788534058101, pvalue=0.13122597380753895, df=2457.0)),
#  ('시가_대비_종가_등락률',
#   TtestResult(statistic=1.4938372958863897, pvalue=0.13534655476211693, df=2457.0)),
#  ('EMA_60',
#   TtestResult(statistic=-1.4702304751561748, pvalue=0.14162738359219681, df=2457.0)),
#  ('[일]국가지자체_수량',
#   TtestResult(statistic=1.465250018083793, pvalue=0.14298066561882408, df=2457.0)),
#  ('[일]외국인_수량',
#   TtestResult(statistic=1.459214877659925, pvalue=0.1446338045289796, df=2457.0)),
#  ('SMA_60_minus_SMA_120',
#   TtestResult(statistic=1.4561028781583487, pvalue=0.1454919471159508, df=2457.0)),
#  ('SMA_20_minus_SMA_240',
#   TtestResult(statistic=1.4346081070233854, pvalue=0.15152606802334145, df=2457.0)),
#  ('EMA_20_minus_EMA_240',
#   TtestResult(statistic=1.4300506442744763, pvalue=0.15282963044622497, df=2457.0)),
#  ('SMA_60',
#   TtestResult(statistic=-1.4287197476622049, pvalue=0.15321191032219106, df=2457.0)),
#  ('SMA_5',
#   TtestResult(statistic=-1.4016677063111602, pvalue=0.161140806417367, df=2457.0)),
#  ('EMA_5',
#   TtestResult(statistic=-1.3769290377784478, pvalue=0.16865962805771478, df=2457.0)),
#  ('시가',
#   TtestResult(statistic=-1.3640360870763235, pvalue=0.1726811448857386, df=2457.0)),
#  ('시가_등락률',
#   TtestResult(statistic=1.3632549450572282, pvalue=0.17292708122917008, df=2457.0)),
#  ('[일]금융투자_수량',
#   TtestResult(statistic=1.3607013634620215, pvalue=0.1737328845376489, df=2457.0)),
#  ('EMA_20',
#   TtestResult(statistic=-1.3515936610623207, pvalue=0.17662975817850882, df=2457.0)),
#  ('저가',
#   TtestResult(statistic=-1.330063955869434, pvalue=0.18362064891606475, df=2457.0)),
#  ('[일]연기금 등_수량',
#   TtestResult(statistic=1.330041924439278, pvalue=0.18362790626764988, df=2457.0)),
#  ('종가',
#   TtestResult(statistic=-1.321264420036681, pvalue=0.18653623874581524, df=2457.0)),
#  ('SMA_20',
#   TtestResult(statistic=-1.318380359529475, pvalue=0.18749923575110652, df=2457.0)),
#  ('[일]은행_수량',
#   TtestResult(statistic=1.3096480001261344, pvalue=0.19043738573991817, df=2457.0)),
#  ('고가_대비_종가_등락률',
#   TtestResult(statistic=-1.2806249941146863, pvalue=0.2004462904835243, df=2457.0)),
#  ('고가',
#   TtestResult(statistic=-1.2794621775414192, pvalue=0.20085515804245146, df=2457.0)),
#  ('종가_minus_EMA_240',
#   TtestResult(statistic=1.255277360107873, pvalue=0.20949746294101276, df=2457.0)),
#  ('종가_minus_SMA_240',
#   TtestResult(statistic=1.254140333913326, pvalue=0.20991030418339973, df=2457.0)),
#  ('SMA_60_등락률',
#   TtestResult(statistic=1.2459048231514442, pvalue=0.2129181257879903, df=2457.0)),
#  ('[일]기타법인_수량',
#   TtestResult(statistic=-1.2377705434765085, pvalue=0.21591941917278853, df=2457.0)),
#  ('SMA_120_minus_SMA_240',
#   TtestResult(statistic=1.2185114138558557, pvalue=0.22314667485002404, df=2457.0)),
#  ('종가_minus_SMA_5',
#   TtestResult(statistic=1.1960363102824827, pvalue=0.23179779831992645, df=2457.0)),
#  ('EMA_5_minus_EMA_240',
#   TtestResult(statistic=1.1596820958672214, pvalue=0.2462909433344095, df=2457.0)),
#  ('SMA_20_minus_SMA_120',
#   TtestResult(statistic=1.1366783203810777, pvalue=0.2557836326984677, df=2457.0)),
#  ('MACD_Binary',
#   TtestResult(statistic=1.1330009210319592, pvalue=0.25732441314628146, df=2457.0)),
#  ('EMA_20_minus_EMA_120',
#   TtestResult(statistic=1.1322070285122672, pvalue=0.25765788734799067, df=2457.0)),
#  ('SMA_5_minus_SMA_240',
#   TtestResult(statistic=1.109074347849599, pvalue=0.26750665296864923, df=2457.0)),
#  ('RSI_minus_Signal_Binary',
#   TtestResult(statistic=1.0646081779438203, pvalue=0.2871578883259111, df=2457.0)),
#  ('EMA_60_등락률',
#   TtestResult(statistic=1.0491714820380353, pvalue=0.2942023884869503, df=2457.0)),
#  ('종가_minus_EMA_5',
#   TtestResult(statistic=0.9847810613214539, pvalue=0.324828587694588, df=2457.0)),
#  ('SMA_5_minus_SMA_20',
#   TtestResult(statistic=-0.9653570878160165, pvalue=0.33446099184254796, df=2457.0)),
#  ('RSI_등락률',
#   TtestResult(statistic=0.9494705866105009, pvalue=0.34247470436151095, df=2457.0)),
#  ('종가_minus_EMA_120',
#   TtestResult(statistic=0.892467423639621, pvalue=0.3722298430223334, df=2457.0)),
#  ('종가_minus_SMA_120',
#   TtestResult(statistic=0.870461970063819, pvalue=0.38413302836821805, df=2457.0)),
#  ('[일]기타금융_수량',
#   TtestResult(statistic=-0.8631804693707608, pvalue=0.3881224982768522, df=2457.0)),
#  ('SMA_5_등락률',
#   TtestResult(statistic=0.8267267097280615, pvalue=0.40847225573950063, df=2457.0)),
#  ('EMA_20_등락률',
#   TtestResult(statistic=0.8131733191170525, pvalue=0.4161974835467481, df=2457.0)),
#  ('EMA_5_minus_EMA_120',
#   TtestResult(statistic=0.7608843190877691, pvalue=0.4467991797856894, df=2457.0)),
#  ('MACD_minus_Signal_Binary',
#   TtestResult(statistic=0.7408727199239993, pvalue=0.45884141451906624, df=2457.0)),
#  ('SMA_5_minus_SMA_120',
#   TtestResult(statistic=0.6723639408220753, pvalue=0.5014152549727003, df=2457.0)),
#  ('저가_대비_종가_등락률',
#   TtestResult(statistic=0.671904549718832, pvalue=0.501707635296247, df=2457.0)),
#  ('EMA_20_minus_EMA_60',
#   TtestResult(statistic=0.6514867897913832, pvalue=0.5147932312021727, df=2457.0)),
#  ('SMA_20_등락률',
#   TtestResult(statistic=0.5865186904044297, pvalue=0.5575808852918531, df=2457.0)),
#  ('[일]프로그램순매수(종목)',
#   TtestResult(statistic=-0.5759026704856935, pvalue=0.5647337140249269, df=2457.0)),
#  ('RSI_Signal_등락률',
#   TtestResult(statistic=0.5572477064570898, pvalue=0.5774089576924117, df=2457.0)),
#  ('RSI',
#   TtestResult(statistic=0.5489059527618939, pvalue=0.5831198691710124, df=2457.0)),
#  ('EMA_5_minus_EMA_20',
#   TtestResult(statistic=-0.5372765306774718, pvalue=0.5911252665178632, df=2457.0)),
#  ('SMA_20_minus_SMA_60',
#   TtestResult(statistic=0.48946282510978284, pvalue=0.6245577606205954, df=2457.0)),
#  ('종가_minus_EMA_60',
#   TtestResult(statistic=0.4133161560173704, pvalue=0.6794110632312714, df=2457.0)),
#  ('MACD_등락률',
#   TtestResult(statistic=0.3027220204048241, pvalue=0.7621273405571561, df=2457.0)),
#  ('MACD',
#   TtestResult(statistic=-0.3013979383532495, pvalue=0.7631365713236395, df=2457.0)),
#  ('RSI_Signal',
#   TtestResult(statistic=0.266344022852201, pvalue=0.7899966206310484, df=2457.0)),
#  ('종가_minus_SMA_60',
#   TtestResult(statistic=0.2205339479078616, pvalue=0.8254736592621617, df=2457.0)),
#  ('EMA_5_minus_EMA_60',
#   TtestResult(statistic=0.18783697654226125, pvalue=0.8510199592410617, df=2457.0)),
#  ('종가_minus_SMA_20',
#   TtestResult(statistic=-0.1773502959138206, pvalue=0.8592478649922818, df=2457.0)),
#  ('거래량',
#   TtestResult(statistic=0.16434075043904262, pvalue=0.8694764213804087, df=2457.0)),
#  ('SMA_5_minus_SMA_60',
#   TtestResult(statistic=-0.11221364945942025, pvalue=0.9106631732139652, df=2457.0)),
#  ('거래량_등락률',
#   TtestResult(statistic=0.0744429525782351, pvalue=0.9406639923869105, df=2457.0)),
#  ('종가_minus_EMA_20',
#   TtestResult(statistic=0.06329393634765654, pvalue=0.949537592684272, df=2457.0)),
#  ('MACD_Signal',
#   TtestResult(statistic=-0.005786136784124646, pvalue=0.9953838262841735, df=2457.0))]

# %%
correlations
# Out:
# 시가_대비_고가_등락률          0.072507
# 고가_등락률                0.066202
# [일]기관_수량              0.060561
# [일]개인_수량              0.054217
# [일]사모펀드_수량            0.053211
#                         ...
# 거래량                   0.003315
# SMA_5_minus_SMA_60    0.002264
# 거래량_등락률               0.001502
# 종가_minus_EMA_20       0.001277
# MACD_Signal           0.000117
# Length: 91, dtype: float64

# %%
features_ridge_sorted
# Out:
# [('EMA_5_등락률', 0.1818508627331672),
#  ('EMA_60_등락률', 0.09762334729437239),
#  ('EMA_20_minus_EMA_60', 0.0951192100286683),
#  ('SMA_120_등락률', 0.08486968137200995),
#  ('저가_대비_고가_등락률', 0.07337388259221722),
#  ('저가_대비_종가_등락률', 0.07133322180116497),
#  ('종가_minus_SMA_5', 0.0706080896477293),
#  ('EMA_20_등락률', 0.06560017393384338),
#  ('EMA_240_등락률', 0.06171328560142751),
#  ('EMA_120_minus_EMA_240', 0.061590213368175356),
#  ('시가_대비_저가_등락률', 0.06018989248657758),
#  ('EMA_20_minus_EMA_240', 0.0587025530802531),
#  ('MACD_minus_Signal_Binary', 0.05706832825988663),
#  ('MACD_Binary', 0.056846807892783804),
#  ('EMA_5_minus_EMA_60', 0.056383520451042723),
#  ('종가_minus_SMA_20', 0.055551829102567896),
#  ('SMA_20_등락률', 0.05400371443630546),
#  ('MACD', 0.05385147254261552),
#  ('종가_minus_EMA_60', 0.05378452088131483),
#  ('종가_minus_SMA_240', 0.053675745616683784),
#  ('[일]외국인_수량', 0.052414316662429766),
#  ('종가_minus_SMA_120', 0.05119395307538982),
#  ('종가_minus_EMA_240', 0.050002238879319316),
#  ('EMA_120_등락률', 0.04976958313847425),
#  ('EMA_5_minus_EMA_240', 0.04969080307325846),
#  ('EMA_20_minus_EMA_120', 0.04914255370481735),
#  ('SMA_60_minus_SMA_120', 0.046307136277738234),
#  ('SMA_5_minus_SMA_240', 0.04470411111019612),
#  ('SMA_60_minus_SMA_240', 0.04364658541733646),
#  ('SMA_20_minus_SMA_240', 0.04104403280871993),
#  ('종가_minus_SMA_60', 0.04103038436008832),
#  ('SMA_5_minus_SMA_120', 0.03949204243789087),
#  ('고가_대비_종가_등락률', 0.03924314895901604),
#  ('RSI_minus_Signal_Binary', 0.03791245021569495),
#  ('종가_minus_EMA_120', 0.036664485813555414),
#  ('[일]프로그램순매수(종목)', 0.03636542659402878),
#  ('EMA_5_minus_EMA_120', 0.036216539328859376),
#  ('SMA_20_minus_SMA_120', 0.03545237927537226),
#  ('시가_대비_고가_등락률', 0.03500184899470815),
#  ('EMA_240', 0.03499288949611372),
#  ('EMA_60_minus_EMA_240', 0.033047114837304714),
#  ('MACD_Signal', 0.03177084181261555),
#  ('거래량', 0.031602904658530634),
#  ('SMA_120_minus_SMA_240', 0.031229279901658857),
#  ('MACD_Signal_등락률', 0.03002956620743362),
#  ('고가', 0.029987862127582685),
#  ('시가_등락률', 0.028892628094376344),
#  ('SMA_5_minus_SMA_20', 0.02839305523808011),
#  ('[일]금융투자_수량', 0.02689235615906252),
#  ('[일]개인_수량', 0.026695846596015115),
#  ('RSI_Signal_등락률', 0.026508867137464164),
#  ('고가_등락률', 0.02579854836822733),
#  ('RSI', 0.025346249520834425),
#  ('EMA_120', 0.02473269089452937),
#  ('[일]연기금 등_수량', 0.024680405610829736),
#  ('EMA_60', 0.024467802171246722),
#  ('SMA_5_minus_SMA_60', 0.02373047101522266),
#  ('[일]사모펀드_수량', 0.02359889373823082),
#  ('[일]국가지자체_수량', 0.02199935033784929),
#  ('[일]투신_수량', 0.02135737771823218),
#  ('SMA_5_등락률', 0.02128853667434955),
#  ('SMA_240_등락률', 0.02000446278331458),
#  ('시가', 0.01833031333544738),
#  ('[일]기관_수량', 0.015429654621085115),
#  ('SMA_20_minus_SMA_60', 0.014291727320959652),
#  ('종가_minus_EMA_5', 0.014202596462655231),
#  ('SMA_240', 0.013250035064353974),
#  ('EMA_5', 0.01321003020164449),
#  ('EMA_5_minus_EMA_20', 0.01255868744252292),
#  ('EMA_20', 0.012366335029540931),
#  ('RSI_등락률', 0.011673831669936796),
#  ('종가_등락률', 0.010521174467475927),
#  ('RSI_Signal', 0.009516315026124628),
#  ('저가_등락률', 0.009397313785779196),
#  ('시가_대비_종가_등락률', 0.008091454459201008),
#  ('SMA_5', 0.007994980008605268),
#  ('종가', 0.007900302180608346),
#  ('거래량_등락률', 0.0054401070989369),
#  ('저가', 0.00543338136690262),
#  ('SMA_120', 0.005203443917432687),
#  ('SMA_20', 0.005130406033759194),
#  ('EMA_60_minus_EMA_120', 0.004169235878794864),
#  ('SMA_60_등락률', 0.0033717977472767363),
#  ('SMA_60', 0.002974890212138398),
#  ('[일]은행_수량', 0.002928102076731748),
#  ('[일]기타법인_수량', 0.0027834254879304243),
#  ('종가_minus_EMA_20', 0.002437486756794255),
#  ('[일]보험_수량', 0.0012538311185235212),
#  ('MACD_등락률', 0.0011847882819226246),
#  ('[일]기타금융_수량', 0.000596943363072814),
#  ('Unnamed: 0', 9.391358048560505e-05)]

# %%
features_lasso_sorted
# Out:
# [('시가_대비_고가_등락률', 0.023321478646131155),
#  ('[일]기타법인_수량', 0.0035141399911543065),
#  ('[일]투신_수량', 0.002201178813579943),
#  ('[일]은행_수량', 0.0020398303102264364),
#  ('[일]사모펀드_수량', 0.0013633604431358254),
#  ('[일]기타금융_수량', 0.000619607707141105),
#  ('Unnamed: 0', 6.26379558197587e-05),
#  ('시가', 0.0),
#  ('고가', 0.0),
#  ('저가', 0.0),
#  ('종가', 0.0),
#  ('거래량', 0.0),
#  ('MACD', 0.0),
#  ('MACD_Signal', 0.0),
#  ('RSI', 0.0),
#  ('RSI_Signal', 0.0),
#  ('SMA_5', 0.0),
#  ('SMA_20', 0.0),
#  ('SMA_60', 0.0),
#  ('SMA_120', 0.0),
#  ('SMA_240', 0.0),
#  ('EMA_5', 0.0),
#  ('EMA_20', 0.0),
#  ('EMA_60', 0.0),
#  ('EMA_120', 0.0),
#  ('EMA_240', 0.0),
#  ('SMA_5_minus_SMA_20', 0.0),
#  ('SMA_5_minus_SMA_60', 0.0),
#  ('SMA_5_minus_SMA_120', 0.0),
#  ('SMA_5_minus_SMA_240', 0.0),
#  ('SMA_20_minus_SMA_60', 0.0),
#  ('SMA_20_minus_SMA_120', 0.0),
#  ('SMA_20_minus_SMA_240', 0.0),
#  ('SMA_60_minus_SMA_120', 0.0),
#  ('SMA_60_minus_SMA_240', 0.0),
#  ('SMA_120_minus_SMA_240', 0.0),
#  ('EMA_5_minus_EMA_20', 0.0),
#  ('EMA_5_minus_EMA_60', 0.0),
#  ('EMA_5_minus_EMA_120', 0.0),
#  ('EMA_5_minus_EMA_240', 0.0),
#  ('EMA_20_minus_EMA_60', 0.0),
#  ('EMA_20_minus_EMA_120', 0.0),
#  ('EMA_20_minus_EMA_240', 0.0),
#  ('EMA_60_minus_EMA_120', 0.0),
#  ('EMA_60_minus_EMA_240', 0.0),
#  ('EMA_120_minus_EMA_240', 0.0),
#  ('시가_등락률', 0.0),
#  ('고가_등락률', 0.0),
#  ('저가_등락률', 0.0),
#  ('종가_등락률', 0.0),
#  ('거래량_등락률', 0.0),
#  ('MACD_등락률', 0.0),
#  ('MACD_Signal_등락률', 0.0),
#  ('RSI_등락률', 0.0),
#  ('RSI_Signal_등락률', 0.0),
#  ('SMA_5_등락률', 0.0),
#  ('SMA_20_등락률', 0.0),
#  ('SMA_60_등락률', 0.0),
#  ('SMA_120_등락률', 0.0),
#  ('SMA_240_등락률', 0.0),
#  ('EMA_5_등락률', 0.0),
#  ('EMA_20_등락률', 0.0),
#  ('EMA_60_등락률', 0.0),
#  ('EMA_120_등락률', 0.0),
#  ('EMA_240_등락률', 0.0),
#  ('MACD_Binary', 0.0),
#  ('MACD_minus_Signal_Binary', 0.0),
#  ('RSI_minus_Signal_Binary', 0.0),
#  ('시가_대비_종가_등락률', 0.0),
#  ('시가_대비_저가_등락률', 0.0),
#  ('저가_대비_종가_등락률', 0.0),
#  ('저가_대비_고가_등락률', 0.0),
#  ('고가_대비_종가_등락률', 0.0),
#  ('종가_minus_SMA_5', 0.0),
#  ('종가_minus_SMA_20', 0.0),
#  ('종가_minus_SMA_60', 0.0),
#  ('종가_minus_SMA_120', 0.0),
#  ('종가_minus_SMA_240', 0.0),
#  ('종가_minus_EMA_5', 0.0),
#  ('종가_minus_EMA_20', 0.0),
#  ('종가_minus_EMA_60', 0.0),
#  ('종가_minus_EMA_120', 0.0),
#  ('종가_minus_EMA_240', 0.0),
#  ('[일]국가지자체_수량', 0.0),
#  ('[일]연기금 등_수량', 0.0),
#  ('[일]보험_수량', 0.0),
#  ('[일]금융투자_수량', 0.0),
#  ('[일]기관_수량', 0.0),
#  ('[일]외국인_수량', 0.0),
#  ('[일]개인_수량', 0.0),
#  ('[일]프로그램순매수(종목)', 0.0)]

# %%
features_rf_sorted
# Out:
# [('[일]사모펀드_수량', 0.028795857200085546),
#  ('[일]연기금 등_수량', 0.026802070500966786),
#  ('[일]기타금융_수량', 0.023204433368008353),
#  ('MACD_Signal_등락률', 0.022435172533891247),
#  ('[일]기타법인_수량', 0.022024064965601123),
#  ('거래량_등락률', 0.021780591663213566),
#  ('[일]은행_수량', 0.021659843168878014),
#  ('고가_등락률', 0.021486303701307826),
#  ('[일]금융투자_수량', 0.021442946649626683),
#  ('[일]투신_수량', 0.02133127313994094),
#  ('저가_대비_고가_등락률', 0.0211773988363125),
#  ('시가_대비_고가_등락률', 0.020759971509868445),
#  ('RSI_등락률', 0.020650047921407694),
#  ('거래량', 0.02064608188796103),
#  ('[일]프로그램순매수(종목)', 0.020590247448698296),
#  ('[일]기관_수량', 0.020380090177494595),
#  ('SMA_5_등락률', 0.020024929458561273),
#  ('[일]보험_수량', 0.019871130669643407),
#  ('시가_등락률', 0.01944213762710252),
#  ('MACD_등락률', 0.019097059975496333),
#  ('[일]외국인_수량', 0.018078696833393054),
#  ('저가_등락률', 0.017537596234384188),
#  ('고가_대비_종가_등락률', 0.017441298483181746),
#  ('RSI_Signal_등락률', 0.016745838516865535),
#  ('저가_대비_종가_등락률', 0.016511918977856574),
#  ('시가_대비_저가_등락률', 0.015402120022642614),
#  ('[일]개인_수량', 0.01486152398266325),
#  ('Unnamed: 0', 0.01463723887489489),
#  ('[일]국가지자체_수량', 0.013826012046834903),
#  ('종가_등락률', 0.013706854804197309),
#  ('SMA_240_등락률', 0.012893117057747261),
#  ('RSI', 0.012737648777643457),
#  ('SMA_60_minus_SMA_120', 0.012565116924336586),
#  ('SMA_120_등락률', 0.012232215346897446),
#  ('SMA_20_등락률', 0.012198996955339006),
#  ('RSI_Signal', 0.012070693630390325),
#  ('시가_대비_종가_등락률', 0.012050349393409251),
#  ('SMA_60_등락률', 0.011349832648746429),
#  ('종가_minus_SMA_5', 0.010754722533519168),
#  ('SMA_120_minus_SMA_240', 0.01059932269824936),
#  ('SMA_20_minus_SMA_60', 0.010434486894530708),
#  ('SMA_5_minus_SMA_20', 0.010145173233959637),
#  ('SMA_240', 0.009915291138879598),
#  ('EMA_5_등락률', 0.00946154662751149),
#  ('EMA_120_minus_EMA_240', 0.00945295462468261),
#  ('EMA_240_등락률', 0.0083619656426431),
#  ('SMA_20_minus_SMA_120', 0.008172393622864843),
#  ('EMA_20_등락률', 0.008127786592923817),
#  ('EMA_120_등락률', 0.007544153543341049),
#  ('종가_minus_EMA_5', 0.0075167912834507465),
#  ('MACD_Signal', 0.007446709565826009),
#  ('SMA_60_minus_SMA_240', 0.0073855093483725055),
#  ('MACD', 0.007235684379496148),
#  ('종가_minus_SMA_20', 0.006859269537847178),
#  ('EMA_5_minus_EMA_20', 0.00670367395079024),
#  ('종가_minus_EMA_20', 0.006698938058994828),
#  ('SMA_120', 0.006623855180791097),
#  ('EMA_240', 0.0064228409060127145),
#  ('EMA_60_minus_EMA_120', 0.0063406541852686045),
#  ('SMA_5_minus_SMA_60', 0.0062344991303469295),
#  ('EMA_60_등락률', 0.00617685564595765),
#  ('종가_minus_SMA_60', 0.006132154231549419),
#  ('SMA_20_minus_SMA_240', 0.005889826980746768),
#  ('SMA_60', 0.0056856437250755575),
#  ('EMA_20_minus_EMA_120', 0.00559758560589265),
#  ('SMA_5_minus_SMA_120', 0.005482121050182853),
#  ('SMA_5_minus_SMA_240', 0.005392547705310301),
#  ('EMA_20_minus_EMA_60', 0.005383710968953026),
#  ('SMA_20', 0.005253499879456752),
#  ('EMA_20_minus_EMA_240', 0.00519187265431569),
#  ('종가_minus_EMA_120', 0.005059065726915958),
#  ('종가_minus_SMA_120', 0.004994130671961),
#  ('종가_minus_EMA_60', 0.004882252917100275),
#  ('EMA_60', 0.0048207055187455515),
#  ('종가_minus_SMA_240', 0.004590573487703486),
#  ('EMA_5_minus_EMA_240', 0.004523472766038607),
#  ('EMA_5_minus_EMA_60', 0.0045192043631408505),
#  ('EMA_5_minus_EMA_120', 0.004280972733140594),
#  ('EMA_60_minus_EMA_240', 0.004182471101873977),
#  ('EMA_120', 0.00410039596806549),
#  ('종가_minus_EMA_240', 0.003972916867027862),
#  ('SMA_5', 0.003910662228051907),
#  ('EMA_20', 0.0038977311430580725),
#  ('시가', 0.003673558571606807),
#  ('종가', 0.0034487749161798524),
#  ('저가', 0.0031146763102333514),
#  ('고가', 0.0029561872685639145),
#  ('EMA_5', 0.002759319471599),
#  ('MACD_minus_Signal_Binary', 0.0007857187571137311),
#  ('RSI_minus_Signal_Binary', 0.00040331937358102323),
#  ('MACD_Binary', 5.1126795065653123e-05)]
